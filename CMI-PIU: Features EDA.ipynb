# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
import torch

# %%
torch.__version__
# Out:
# '2.10.0+cu128'

# %%
import opendatasets as od

# %%
dataset = "https://www.kaggle.com/competitions/child-mind-institute-problematic-internet-use/"

# %%
od.download(dataset)

# %%
import os

# %%
data_dir = '.\'
