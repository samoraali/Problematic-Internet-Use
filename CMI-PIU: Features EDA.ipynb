# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %pip install lxml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 45.1 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml

# %%
# %pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
URL = 'https://drive.google.com/drive/folders/1aogjviHctYhlYm-pcE0RVHDD6Bla-VAS?usp=sharing'
dataset = pd.read_html(URL)

# %%
print(dataset)
# Out:
# [                           Naam Date modified  File size  \
# 0           series_test.parquet        16 feb        â
# 1          series_train.parquet        16 feb        â
# 2              .DS_StoreGedeeld        11 feb       8 KB
# 3    data_dictionary.csvGedeeld   14 nov 2024      10 KB
# 4  sample_submission.csvGedeeld   14 nov 2024  227 bytes
# 5               test.csvGedeeld   14 nov 2024       4 KB
# 6              train.csvGedeeld   14 nov 2024     923 KB
#
#   Sorteeropties bekijkenSorterenSorteeropties bekijkenSorteren opNaamDate modifiedSorteerrichtingA to ZZ to AMappenBovenaanTussen de bestanden
# 0                                         Downloaden
# 1                                         Downloaden
# 2                                         Downloaden
# 3                                         Downloaden
# 4                                         Downloaden
# 5                                         Downloaden
# ...

# %%
training_data = pd.read_parquet(dataset(series_train.parquet), engine=auto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 training_data = pd.read_parquet(dataset(series_train.parquet), engine=auto)
#
# NameError: name 'series_train' is not defined
