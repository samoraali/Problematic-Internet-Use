# %% [markdown]
# <a href="https://colab.research.google.com/github/samoraali/Problematic-Internet-Use/blob/main/PIU_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
# You may need to re-run this cell after logging in.
kagglehub.login()
path = kagglehub.competition_download('child-mind-institute-problematic-internet-use')
# Out:
# ...
# 100%|██████████| 6.21G/6.21G [01:10<00:00, 94.7MB/s]
# Extracting files...

# %%
# !ls -la /root/.cache/kagglehub/competitions/child-mind-institute-problematic-internet-use
# Out:
# ls: cannot access '/root/.cache/kagglehub/competitions/child-mind-institute-problematic-internet-use': No such file or directory

# %%
# !mkdir -p /content/cmi_piu

# %%
# !cp -r /root/.cache/kagglehub/competitions/child-mind-institute-problematic-internet-use/* /content/cmi_piu/
# Out:
# cp: cannot stat '/root/.cache/kagglehub/competitions/child-mind-institute-problematic-internet-use/*': No such file or directory

# %%
#Trying gdown for using with this dataset
#!pip -q install gdown==4.6.0
#import gdown

# %%
# !ls -la /content/cmi_piu
# Out:
# total 8
# drwxr-xr-x 2 root root 4096 Apr  7 08:44 .
# drwxr-xr-x 1 root root 4096 Apr  7 08:44 ..

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('/content/cmi_piu/train.csv')

# %%
print(train_data)
# Out:
#             id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0     00008ff9                      Fall                5                0
# 1     000fd460                    Summer                9                0
# 2     00105258                    Summer               10                1
# 3     00115b9f                    Winter                9                0
# 4     0016bb22                    Spring               18                1
# ...        ...                       ...              ...              ...
# 3955  ff8a2de4                      Fall               13                0
# 3956  ffa9794a                    Winter               10                0
# 3957  ffcd4dbd                      Fall               11                0
# 3958  ffed1dd5                    Spring               13                0
# 3959  ffef538e                    Spring               11                0
#
#      CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  \
# ...

# %%
print(train_data.columns)
# Out:
# Index(['id', 'Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
#        'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
#        'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
#        'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
#        'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
#        'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
#        'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
#        'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
#        'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
#        'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
#        'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
#        'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
#        'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
# ...

# %%
data_dictionary = pd.read_csv('/content/cmi_piu/data_dictionary.csv')

# %%
print(data_dictionary)
# Out:
#                             Instrument  \
# 0                           Identifier
# 1                         Demographics
# 2                         Demographics
# 3                         Demographics
# 4   Children's Global Assessment Scale
# ..                                 ...
# 76             Sleep Disturbance Scale
# 77             Sleep Disturbance Scale
# 78             Sleep Disturbance Scale
# 79                        Internet Use
# 80                        Internet Use
#
#                                      Field                       Description  \
# 0                                       id                  Participant's ID
# 1                Basic_Demos-Enroll_Season              Season of enrollment
# 2                          Basic_Demos-Age                Age of participant
# 3                          Basic_Demos-Sex                Sex of participant
# 4                              CGAS-Season           Season of participation
# ...

# %%
series_train = pd.read_parquet('/content/cmi_piu/series_train.parquet')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14183/395741249.py in <cell line: 0>()
# ----> 1 series_train = pd.read_parquet('/content/cmi_piu/series_train.parquet')
#
# NameError: name 'pd' is not defined

# %%
series_test = pd.read_parquet('/content/cmi_piu/series_test.parquet')

# %%
series_test.head(100)
# Out:
#     step         X         Y         Z      enmo     anglez  non-wear_flag  \
# 0      0  0.021536  0.022214 -1.022370  0.022853 -88.280762            0.0
# 1      1  0.022005  0.022187 -1.019740  0.020231 -88.241707            0.0
# 2      2  0.022240  0.022005 -1.019401  0.019893 -88.170067            0.0
# 3      3  0.021589  0.022578 -1.018177  0.018667 -88.250031            0.0
# 4      4  0.022005  0.023763 -1.014323  0.016848 -88.130775            0.0
# ..   ...       ...       ...       ...       ...        ...            ...
# 95    95 -0.353516  0.094792 -0.084922  0.549741 -14.866868            0.0
# 96    96 -0.591771 -0.309922 -0.132083  0.653829  -5.153176            0.0
# 97    97 -0.981172 -1.545990 -0.051823  2.435782  -6.059050            0.0
# 98    98 -0.759557 -0.085703 -0.293880  0.462349 -29.177721            0.0
# 99    99 -0.274844  0.074115 -0.632786  0.378578 -44.821960            0.0
#
#         light  battery_voltage     time_of_day  weekday  quarter  \
# ...
